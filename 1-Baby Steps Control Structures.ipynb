# %%
print ("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=int(input("Enter the value for Num1:"))
Num2=int(input("Enter the value for Num2:"))
# Out:
# Enter the value for Num1: 100
# Enter the value for Num2: 100

# %%
print("Num1=",Num1)
print("Num2=",Num2)
Add=Num1+Num2
print("Add=",Add)
# Out:
# Num1= 100
# Num2= 100
# Add= 200

# %%
BMI=float(input("Enter the BMI Index:"))
# Out:
# Enter the BMI Index: 33.9

# %%
if BMI>=34:
    print("Very Over Weight")
else:
    print("Normal Weight")
# Out:
# Normal Weight
